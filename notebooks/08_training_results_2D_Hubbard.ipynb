# %% [markdown]
# # Compare training results for different targets and models

# %% [markdown]
# We have access to data from our training benchmarks in [`data`](../data/), where we can find different folders for different target quantum Hamiltonians:
#
# 1. [tfim](../data/tfim/): 1D Transverse Field Ising Model (spin)
#     $$
#     H =
#     \sum_{i=1}^{n-1} J_{i,i+1} Z_{i}Z_{i+1}
#     +
#     \sum_{i=1}^{n} B_i X_{i}.
#     $$
# 2. [1d_heisenberg](../data/1d_heisenberg/): 1D Heisenberg model (spin)
#    $$
#     H =
#     \sum_{i=1}^{n-1}(J^{X}_{i,i+1}X_{i}X_{i+1}+J^{Y}_{i,i+1}Y_{i}Y_{i+1}+J^{Z}_{i,i+1}Z_{i}Z_{i+1})
#     +
#     \sum_{i=1}^{n}B_i Z_{i}.
#    $$
# 3. [1d_hubbard](../data/1d_hubbard/): 1D Hubbard model (fermion) [The system size is chosen so that the number of sites becomes $n$ after fermionic operators are mapped to spin operators via the Jordan-Wigner transformations]
#    $$
#     H =
#     -\sum_{j=1}^{n/2-1}\sum_{\sigma\in\{\uparrow,\downarrow\}}
#     t_{j,j+1}^{\sigma}(\psi_{j,\sigma}^\dag\psi_{j+1,\sigma} + \psi_{j+1,\sigma}^\dag\psi_{j,\sigma})
#     +
#     \sum_{j=1}^{n/2-1}
#     \mu_{j}\left(\psi_{j,\uparrow}^\dag\psi_{j,\uparrow}-\frac{1}{2}\right)
#     \left(\psi_{j,\downarrow}^\dag\psi_{j,\downarrow}-\frac{1}{2}\right).
#    $$
# 4. [2d_hubbard](../data/2d_hubbard/): 2D Hubbard model (fermion) [The integer $n$ is assumed to be divisible by $4$ and equals to or greater than $8$.
# The system size is chosen so that the number of sites becomes $n$ after fermionic operators are mapped to spin operators via the Jordan-Wigner transformations]
#    $$
#     H =
#     -\sum_{\sigma\in\{\uparrow,\downarrow\}}
#     \big[
#     \underbrace{\sum_{j_x=1}^{n/4-1}\sum_{j_y=1,2}
#     t_{\boldsymbol{j},\boldsymbol{j}+\boldsymbol{e}_x}^{\sigma}(\psi_{\boldsymbol{j},\sigma}^\dag\psi_{\boldsymbol{j}+\boldsymbol{e}_x,\sigma} + \psi_{\boldsymbol{j}+\boldsymbol{e}_x,\sigma}^\dag\psi_{\boldsymbol{j},\sigma})}_{\text{hoppings in $x$ direction}}
#     \\
#     \qquad\qquad+
#     \underbrace{\sum_{j_x=1}^{n/4}
#     t_{(j_x,1),(j_x,2)}^{\sigma}(\psi_{(j_x,1),\sigma}^\dag\psi_{(j_x,2),\sigma} + \psi_{(j_x,2),\sigma}^\dag\psi_{(j_x,1),\sigma})}_{\text{hoppings in $y$ direction}}
#     \big]
#     \\
#     +
#     \sum_{j_x=1}^{n/4}\sum_{j_y=1,2}
#     \mu_{\boldsymbol{j}}\left(\psi_{\boldsymbol{j},\uparrow}^\dag\psi_{\boldsymbol{j},\uparrow}-\frac{1}{2}\right)
#     \left(\psi_{\boldsymbol{j},\downarrow}^\dag\psi_{\boldsymbol{j},\downarrow}-\frac{1}{2}\right),
#    $$
#    with $\boldsymbol{j}:=(j_x, j_y)$, $\boldsymbol{e}_x:=(1,0)$, and $\boldsymbol{e}_y:=(1,0)$.

# %% [markdown]
# ## 2D Hubbard model
#
# In this section we collect results for the 2D Hubbard model.
# We prepare different target Gibbs states with the Hubbard Hamiltonian by fixing the couplings and the inverse temperature.
#
# $t^\sigma_{i,j} = t$ and $\mu_i = \mu$ for each qubit $i,j$.
#
# The inverse temperature $\beta = 1/T$ takes values in ${0.5, 1, 4, 10, 100}$, and the corresponding Gibbs state is
# $$
# \eta(\beta) = \frac{e^{-\beta H}}{\mathrm{Tr}[e^{-\beta H}]}
# $$

# %% [markdown]
# ### Model 0: QBM Hamiltonian is the same as the target Hamiltonian
#
# We start by selecting a Quantum Boltzmann Machine model whose Hamiltonian is the same as the target one. In this case there is no model mismatch, that is, the QBM can exactly represent all the Gibbs states of the TFIM.
#
# The definition of our QBM is
# $$
# \rho_\theta = \frac{e^{H_\theta}}{Z}.
# $$

# %%
def stringify(p: float):
    return str(round(p,5)).replace(".", "-")


def get_exp_name(
    target_label,
    target_beta,
    n_qubits,
    model_label,
    epochs,
    learning_rate,
    shot_noise_sigma,
    depolarizing_noise,
):
    return (
        f"t{target_label}_"
        + f"beta{stringify(target_beta)}_"
        + f"q{n_qubits}_"
        + f"qbm{model_label}_"
        + f"e{epochs}_"
        + f"lr{stringify(learning_rate)}_"
        + f"sn{stringify(shot_noise_sigma)}_"
        + f"dn{stringify(depolarizing_noise)}"
    )

# %%
import os

output_path = "../data/2d_hubbard"

files = os.listdir(f"{output_path}/histories/")
grads = [f for f in files if "Grad" in f]
qre = [f for f in files if "QRE" in f]

# %% [markdown]
# Se the parameters of the experiments that we do not want to change:

# %%
target_label = 5
target_beta = 1.0
model_label = 5
epochs = 1000
learning_rate = 0.25
shot_noise_sigma = 0.0
depolarizing_noise = 0.0

# %% [markdown]
# Let's look at the training history as a function of the number of qubits.
# Remember that here we are only learning 2 parameters, and we are plotting the maximum value of the gradients at each iteration of the stochastic gradient descent algorithm.

# %%
all_qubits = [8]

# %%
import numpy as np

max_grads_hist = []
n = []
for n_qubits in all_qubits:
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    grad_file = f"MaxGrad_{exp_name}.npy"
    if grad_file in files:
        max_grads_hist.append(np.load(f"{output_path}/histories/{grad_file}"))
        print(f"Reading file {grad_file}")
        n.append(n_qubits)
    else:
        print(f"Missing file {grad_file}")
# Out:
# Reading file MaxGrad_t5_beta1-0_q8_qbm5_e1000_lr0-25_sn0-0_dn0-0.npy

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))
for hist in max_grads_hist:
    ax.plot(hist, "-")
ax.set_xlabel("Epoch")
ax.set_ylabel("Max absolute value of gradients")
ax.set_yscale("log")
ax.legend([f"n={_}" for _ in n])

for _n, hist in zip(n, max_grads_hist):
    print(f"n = {_n}, max grad (first, last): {hist[0]}, {hist[-1]}")
# Out:
# n = 8, max grad (first, last): 1.2977068058938697, 9.641293286788422e-07

# %% [markdown]
# The plot above does not go below `1e-6` because we stop the training when the gradients are smaller than this threshold value. In all effects, we consider that the training has converged. Remember that the loss function landscape is convex and that the minimum is reached when the gradients are zero.

# %% [markdown]
# We can make a similar plot for the quantum relative entropy during the training iterations. Since there is no model mismatch (target and model Hamiltonian are the same), we expect that the relative entropy goes to zero at the end of the training.

# %%
qre_hist = []
n = []
for n_qubits in all_qubits:
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    qre_file = f"QRE_{exp_name}.npy"
    if qre_file in files:
        qre_hist.append(np.load(f"{output_path}/histories/{qre_file}"))
        print(f"Reading file {qre_file}")
        n.append(n_qubits)
    else:
        print(f"Missing file {qre_file}")
# Out:
# Reading file QRE_t5_beta1-0_q8_qbm5_e1000_lr0-25_sn0-0_dn0-0.npy

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))
for hist in qre_hist:
    ax.plot(hist, "-")
ax.set_xlabel("Epoch")
ax.set_ylabel("Quantum Relative Entropy")
ax.set_yscale("log")
ax.legend([f"n={_}" for _ in n])

for _n, hist in zip(n, qre_hist):
    print(f"n = {_n}, QRE (first, last): {hist[0]}, {hist[-1]}")
# Out:
# n = 8, QRE (first, last): 0.2910981902208736, 1.8669510382096632e-12

# %%
results_files = os.listdir(f"{output_path}/results/")
target_params = []
model_params = []

n = []
for n_qubits in all_qubits:
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    true_params_file = f"ParamsTrue_{exp_name}.npy"
    model_params_file = f"Params_{exp_name}.npy"
    if true_params_file in results_files:
        target_params.append(np.load(f"{output_path}/results/{true_params_file}"))
        print(f"Reading file {true_params_file}")
        n.append(n_qubits)
        if model_params_file in results_files:
            model_params.append(np.load(f"{output_path}/results/{model_params_file}"))
            print(f"Reading file {model_params_file}")
        else:
            print(f"Missing file {model_params_file}")
    else:
        print(f"Missing file {target_params}")
# Out:
# Reading file ParamsTrue_t5_beta1-0_q8_qbm5_e1000_lr0-25_sn0-0_dn0-0.npy
# Reading file Params_t5_beta1-0_q8_qbm5_e1000_lr0-25_sn0-0_dn0-0.npy

# %%
for _n, _target_params, _model_params in zip(n, target_params, model_params):
    print(f"n = {_n}, target params: {_target_params}")
    print(f"   --- model params after training: {_model_params}")
    print(f"   --- (beta-normalized) model params after training: {_model_params/(-target_beta)}"
    )
# Out:
# n = 8, target params: [0.34558419 0.82161814]
#    --- model params after training: [-0.3455841  -0.82161404]
#    --- (beta-normalized) model params after training: [0.3455841  0.82161404]

# %% [markdown]
# We can also check the training histories as a function of the inverse temperature $\beta$

# %%
all_betas = [0.5, 1.0, 2.0, 4.0]
n_qubits = 8

# %%
qre_hist = []
b = []
for target_beta in all_betas:
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    qre_file = f"QRE_{exp_name}.npy"
    if qre_file in files:
        qre_hist.append(np.load(f"{output_path}/histories/{qre_file}"))
        print(f"Reading file {qre_file}")
        b.append(target_beta)
    else:
        print(f"Missing file {qre_file}")
# Out:
# Reading file QRE_t5_beta0-5_q8_qbm5_e1000_lr0-25_sn0-0_dn0-0.npy
# Reading file QRE_t5_beta1-0_q8_qbm5_e1000_lr0-25_sn0-0_dn0-0.npy
# Reading file QRE_t5_beta2-0_q8_qbm5_e1000_lr0-25_sn0-0_dn0-0.npy
# Reading file QRE_t5_beta4-0_q8_qbm5_e1000_lr0-25_sn0-0_dn0-0.npy

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))
for hist in qre_hist:
    ax.plot(hist[1:], "-")
ax.set_xlabel("Epoch")
ax.set_ylabel("Quantum Relative Entropy")
ax.set_yscale("log")
ax.legend([rf"$\beta$={_}" for _ in b])

# %% [markdown]
# ### Model 6: 1D GL spin model
#
# Next, we select a Quantum Boltzmann Machine model whose Hamiltonian is
# $$
# \rho_\theta = \frac{e^{H_\theta}}{Z}
# $$
# where
# $$
# H_\theta =
# \sum_{i=1}^{n-1}(\theta^X_{i,i+1}X_{i}X_{i+1} + \theta^Y_{i,i+1}Y_{i}Y_{i+1} + \theta^Z_{i,i+1}Z_{i}Z_{i+1})
# +
# \sum_{i=1}^{n}(\theta^X_i X_{i} + \theta^Y_i Y_{i} + \theta^Z_i Z_{i})
# $$
# and $Z=\mathrm{Tr}[e^{H_\theta}]$.

# %%
target_label = 5
target_beta = 1.0
model_label = 6
epochs = 1000
shot_noise_sigma = 0.0
depolarizing_noise = 0.0

# %%
all_qubits = [8]  # 10 , 12]
learning_rates = 1 / (2 * (np.asarray(all_qubits) * 6 - 3))
print(f"Qubits: {all_qubits}")
print("Learning rates: [", " ".join(f"{_:.5f}" for _ in learning_rates), "]")
# Out:
# Qubits: [8]
# Learning rates: [ 0.01111 ]

# %%
import numpy as np

max_grads_hist = []
n = []
for n_qubits, learning_rate in zip(all_qubits, learning_rates):
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    grad_file = f"MaxGrad_{exp_name}.npy"
    if grad_file in files:
        max_grads_hist.append(np.load(f"{output_path}/histories/{grad_file}"))
        print(f"Reading file {grad_file}")
        n.append(n_qubits)
    else:
        print(f"Missing file {grad_file}")
# Out:
# Reading file MaxGrad_t5_beta1-0_q8_qbm6_e1000_lr0-01111_sn0-0_dn0-0.npy

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))
for hist in max_grads_hist:
    ax.plot(hist, "-")
ax.set_xlabel("Epoch")
ax.set_ylabel("Max absolute value of gradients")
ax.set_yscale("log")
ax.legend([f"n={_}" for _ in n])

for _n, hist in zip(n, max_grads_hist):
    print(f"n = {_n}, max grad (first, last): {hist[0]}, {hist[-1]}")
# Out:
# n = 8, max grad (first, last): 0.18821923918741942, 3.7683219067108364e-06

# %%
qre_hist = []
n = []
for n_qubits, learning_rate in zip(all_qubits, learning_rates):
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    qre_file = f"QRE_{exp_name}.npy"
    if qre_file in files:
        qre_hist.append(np.load(f"{output_path}/histories/{qre_file}"))
        print(f"Reading file {qre_file}")
        n.append(n_qubits)
    else:
        print(f"Missing file {qre_file}")
# Out:
# Reading file QRE_t5_beta1-0_q8_qbm6_e1000_lr0-01111_sn0-0_dn0-0.npy

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))
for hist in qre_hist:
    ax.plot(hist, "-")
ax.set_xlabel("Epoch")
ax.set_ylabel("Quantum Relative Entropy")
ax.set_yscale("log")
ax.legend([f"n={_}" for _ in n])

for _n, hist in zip(n, qre_hist):
    print(f"n = {_n}, QRE (first, last): {hist[0]}, {hist[-1]}")
# Out:
# n = 8, QRE (first, last): 0.2910981902208736, 0.21980809581847005

# %%
results_files = os.listdir(f"{output_path}/results/")
target_params = []
model_params = []

n = []
for n_qubits, learning_rate in zip(all_qubits, learning_rates):
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    true_params_file = f"ParamsTrue_{exp_name}.npy"
    model_params_file = f"Params_{exp_name}.npy"
    if true_params_file in results_files:
        target_params.append(np.load(f"{output_path}/results/{true_params_file}"))
        print(f"Reading file {true_params_file}")
        n.append(n_qubits)
        if model_params_file in results_files:
            model_params.append(np.load(f"{output_path}/results/{model_params_file}"))
            print(f"Reading file {model_params_file}")
        else:
            print(f"Missing file {model_params_file}")
    else:
        print(f"Missing file {target_params}")
# Out:
# Reading file ParamsTrue_t5_beta1-0_q8_qbm6_e1000_lr0-01111_sn0-0_dn0-0.npy
# Reading file Params_t5_beta1-0_q8_qbm6_e1000_lr0-01111_sn0-0_dn0-0.npy

# %%
for _n, _target_params, _model_params in zip(n, target_params, model_params):
    print(f"n = {_n}, target params: {_target_params}")
    print(f"   --- model params after training: {_model_params}")
    print(f"   --- (beta-normalized) model params after training: {_model_params/(-target_beta)}"
    )
# Out:
# n = 8, target params: [0.34558419 0.82161814]
#    --- model params after training: [ 2.69239916e-17 -1.49391100e-17 -1.50797772e-17  2.94156372e-17
#   6.74996350e-18  7.14530842e-19  2.78710245e-17 -3.03986809e-18
#  -4.07849354e-18 -2.34131276e-18  1.47702047e-17  8.24437118e-19
#   6.53715536e-18  1.21575681e-17 -1.71412885e-17  8.23523713e-18
#  -3.12792515e-17  1.75931712e-17 -4.58381378e-19  1.04863753e-17
#   4.03985801e-17  1.21700100e-17  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.90486497e-01  3.56609434e-03
#  -1.90486497e-01 -2.22110162e-04 -1.90486497e-01  3.56609434e-03
#  -1.90486497e-01  1.61914752e-16  5.33596123e-17  7.04755505e-17
#  -4.41703965e-17  3.40463576e-17  5.64242904e-17 -5.19188280e-17
#  -2.92541840e-17]
#    --- (beta-normalized) model params after training: [-2.69239916e-17  1.49391100e-17  1.50797772e-17 -2.94156372e-17
#  -6.74996350e-18 -7.14530842e-19 -2.78710245e-17  3.03986809e-18
#   4.07849354e-18  2.34131276e-18 -1.47702047e-17 -8.24437118e-19
#  -6.53715536e-18 -1.21575681e-17  1.71412885e-17 -8.23523713e-18
#   3.12792515e-17 -1.75931712e-17  4.58381378e-19 -1.04863753e-17
#  -4.03985801e-17 -1.21700100e-17 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00  1.90486497e-01 -3.56609434e-03
#   1.90486497e-01  2.22110162e-04  1.90486497e-01 -3.56609434e-03
#   1.90486497e-01 -1.61914752e-16 -5.33596123e-17 -7.04755505e-17
#   4.41703965e-17 -3.40463576e-17 -5.64242904e-17  5.19188280e-17
#   2.92541840e-17]

# %% [markdown]
# ### Model 8: QBM Hamiltonian contains the target Hamiltonian
#
# We move on to the QBM model whose Hamiltonian is
# $$
# H_\theta =
# \sum_{i,j>i}(\theta^X_{i,j}X_{i}X_{j} + \theta^Y_{i,j}Y_{i}Y_{j} + \theta^Z_{i,j}Z_{i}Z_{j})
# +
# \sum_{i}(\theta^X_i X_{i} + \theta^Y_i Y_{i} + \theta^Z_i Z_{i})
# $$
# and $Z=\mathrm{Tr}[e^{H_\theta}]$.

# %%
target_label = 5
target_beta = 1.0
model_label = 8
epochs = 1000
shot_noise_sigma = 0.0
depolarizing_noise = 0.0

# %%
all_qubits = [8]  # 10 , 12]
learning_rates = 1 / (3 * (np.asarray(all_qubits) * (np.asarray(all_qubits) + 1)))
print(f"Qubits: {all_qubits}")
print("Learning rates: [", " ".join(f"{_:.5f}" for _ in learning_rates), "]")
# Out:
# Qubits: [8]
# Learning rates: [ 0.00463 ]

# %%
import numpy as np

max_grads_hist = []
n = []
for n_qubits, learning_rate in zip(all_qubits, learning_rates):
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    grad_file = f"MaxGrad_{exp_name}.npy"
    if grad_file in files:
        max_grads_hist.append(np.load(f"{output_path}/histories/{grad_file}"))
        print(f"Reading file {grad_file}")
        n.append(n_qubits)
    else:
        print(f"Missing file {grad_file}")
# Out:
# Reading file MaxGrad_t5_beta1-0_q8_qbm8_e1000_lr0-00463_sn0-0_dn0-0.npy

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))
for hist in max_grads_hist:
    ax.plot(hist, "-")
ax.set_xlabel("Epoch")
ax.set_ylabel("Max absolute value of gradients")
ax.set_yscale("log")
ax.legend([f"n={_}" for _ in n])

for _n, hist in zip(n, max_grads_hist):
    print(f"n = {_n}, max grad (first, last): {hist[0]}, {hist[-1]}")
# Out:
# n = 8, max grad (first, last): 0.18821923918741942, 0.0021596230484582646

# %%
qre_hist = []
n = []
for n_qubits, learning_rate in zip(all_qubits, learning_rates):
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    qre_file = f"QRE_{exp_name}.npy"
    if qre_file in files:
        qre_hist.append(np.load(f"{output_path}/histories/{qre_file}"))
        print(f"Reading file {qre_file}")
        n.append(n_qubits)
    else:
        print(f"Missing file {qre_file}")
# Out:
# Reading file QRE_t5_beta1-0_q8_qbm8_e1000_lr0-00463_sn0-0_dn0-0.npy

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))
for hist in qre_hist:
    ax.plot(hist, "-")
ax.set_xlabel("Epoch")
ax.set_ylabel("Quantum Relative Entropy")
ax.set_yscale("log")
ax.legend([f"n={_}" for _ in n])

for _n, hist in zip(n, qre_hist):
    print(f"n = {_n}, QRE (first, last): {hist[0]}, {hist[-1]}")
# Out:
# n = 8, QRE (first, last): 0.2910981902208736, 0.21674437272014924

# %%
results_files = os.listdir(f"{output_path}/results/")
target_params = []
model_params = []

n = []
for n_qubits, learning_rate in zip(all_qubits, learning_rates):
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    true_params_file = f"ParamsTrue_{exp_name}.npy"
    model_params_file = f"Params_{exp_name}.npy"
    if true_params_file in results_files:
        target_params.append(np.load(f"{output_path}/results/{true_params_file}"))
        print(f"Reading file {true_params_file}")
        n.append(n_qubits)
        if model_params_file in results_files:
            model_params.append(np.load(f"{output_path}/results/{model_params_file}"))
            print(f"Reading file {model_params_file}")
        else:
            print(f"Missing file {model_params_file}")
    else:
        print(f"Missing file {target_params}")
# Out:
# Reading file ParamsTrue_t5_beta1-0_q8_qbm8_e1000_lr0-00463_sn0-0_dn0-0.npy
# Reading file Params_t5_beta1-0_q8_qbm8_e1000_lr0-00463_sn0-0_dn0-0.npy

# %%
for _n, _target_params, _model_params in zip(n, target_params, model_params):
    print(f"n = {_n}, target params: {_target_params}")
    print(f"   --- model params after training: {_model_params}")
    print(f"   --- (beta-normalized) model params after training: {_model_params/(-target_beta)}"
    )
# Out:
# n = 8, target params: [0.34558419 0.82161814]
#    --- model params after training: [ 2.86187291e-17 -3.44465873e-17 -2.98209669e-17 -1.22588608e-17
#  -2.02636879e-17  3.00575194e-04  2.82962445e-18 -9.46913997e-18
#   1.02001511e-17  5.02061269e-18 -1.41214299e-17  4.01322492e-18
#   3.00575194e-04 -1.85592320e-17 -3.46660750e-03  1.14422797e-17
#   7.83864860e-18  1.15069713e-17  1.35009613e-17 -3.46660750e-03
#  -1.43714504e-17 -3.67095064e-18  5.92545148e-18  1.09503998e-17
#   1.57741105e-17  5.42914909e-18 -1.06336543e-18  3.02847922e-17
#  -3.10719304e-18 -4.45248163e-18 -1.77742899e-18  1.40817228e-17
#  -6.03553846e-20  5.65058408e-18  1.16605090e-17 -1.74932948e-17
#   6.31185010e-18 -3.92800137e-17 -1.14991053e-17 -1.22801452e-17
#  -1.81391983e-17  3.00575194e-04  2.02271790e-18 -1.94349487e-17
#   1.50073471e-17 -1.40597246e-17 -1.23489844e-17  1.72678960e-17
#   3.00575194e-04  1.82638829e-17 -3.46660750e-03 -4.25487704e-18
#  -1.66243483e-18 -1.09395053e-17  1.92720121e-18 -3.46660750e-03
#  -1.50594648e-17  9.99034020e-18  1.23154316e-17 -2.27760955e-18
#   4.89261736e-18  3.07326982e-17 -2.79087566e-18  9.69381619e-18
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -1.88606748e-01 -2.78971908e-02 -5.80512696e-03 -2.78971908e-02
#  -5.80512696e-03 -1.32959775e-03 -3.58534380e-04 -5.80512696e-03
#  -2.78971908e-02 -5.80512696e-03 -2.78971908e-02 -3.58534380e-04
#  -1.32959775e-03 -1.88609407e-01 -1.31851999e-03 -3.56520177e-04
#  -2.78971908e-02 -5.80512696e-03 -3.56520177e-04 -1.31851999e-03
#  -5.80512696e-03 -2.78971908e-02 -1.88609407e-01 -2.78971908e-02
#  -5.80512696e-03 -5.80512696e-03 -2.78971908e-02 -1.88606748e-01
#   1.54489775e-16  3.56290919e-17  4.50736975e-17 -3.90603910e-17
#   3.30109445e-17  2.64575447e-17 -1.91753201e-17  3.73517687e-17]
#    --- (beta-normalized) model params after training: [-2.86187291e-17  3.44465873e-17  2.98209669e-17  1.22588608e-17
#   2.02636879e-17 -3.00575194e-04 -2.82962445e-18  9.46913997e-18
#  -1.02001511e-17 -5.02061269e-18  1.41214299e-17 -4.01322492e-18
#  -3.00575194e-04  1.85592320e-17  3.46660750e-03 -1.14422797e-17
#  -7.83864860e-18 -1.15069713e-17 -1.35009613e-17  3.46660750e-03
#   1.43714504e-17  3.67095064e-18 -5.92545148e-18 -1.09503998e-17
#  -1.57741105e-17 -5.42914909e-18  1.06336543e-18 -3.02847922e-17
#   3.10719304e-18  4.45248163e-18  1.77742899e-18 -1.40817228e-17
#   6.03553846e-20 -5.65058408e-18 -1.16605090e-17  1.74932948e-17
#  -6.31185010e-18  3.92800137e-17  1.14991053e-17  1.22801452e-17
#   1.81391983e-17 -3.00575194e-04 -2.02271790e-18  1.94349487e-17
#  -1.50073471e-17  1.40597246e-17  1.23489844e-17 -1.72678960e-17
#  -3.00575194e-04 -1.82638829e-17  3.46660750e-03  4.25487704e-18
#   1.66243483e-18  1.09395053e-17 -1.92720121e-18  3.46660750e-03
#   1.50594648e-17 -9.99034020e-18 -1.23154316e-17  2.27760955e-18
#  -4.89261736e-18 -3.07326982e-17  2.79087566e-18 -9.69381619e-18
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#   1.88606748e-01  2.78971908e-02  5.80512696e-03  2.78971908e-02
#   5.80512696e-03  1.32959775e-03  3.58534380e-04  5.80512696e-03
#   2.78971908e-02  5.80512696e-03  2.78971908e-02  3.58534380e-04
#   1.32959775e-03  1.88609407e-01  1.31851999e-03  3.56520177e-04
#   2.78971908e-02  5.80512696e-03  3.56520177e-04  1.31851999e-03
#   5.80512696e-03  2.78971908e-02  1.88609407e-01  2.78971908e-02
#   5.80512696e-03  5.80512696e-03  2.78971908e-02  1.88606748e-01
#  -1.54489775e-16 -3.56290919e-17 -4.50736975e-17  3.90603910e-17
#  -3.30109445e-17 -2.64575447e-17  1.91753201e-17 -3.73517687e-17]

# %% [markdown]
# ### Model 9: QBM Hamiltonian contains the target Hamiltonian
#
# Finally, we consider the classical BM model whose Hamiltonian is
# $$
# H_\theta =
# \sum_{i,j>i} \theta_{i,j}Z_{i}Z_{j}
# +
# \sum_{i}\theta_i Z_{i}
# $$
# and $Z=\mathrm{Tr}[e^{H_\theta}]$.

# %%
target_label = 5
target_beta = 1.0
model_label = 9
epochs = 1000
shot_noise_sigma = 0.0
depolarizing_noise = 0.0

# %%
all_qubits = [8]  # 10 , 12]
learning_rates = 1 / ((np.asarray(all_qubits) * (np.asarray(all_qubits) + 1)))
print(f"Qubits: {all_qubits}")
print("Learning rates: [", " ".join(f"{_:.5f}" for _ in learning_rates), "]")
# Out:
# Qubits: [8]
# Learning rates: [ 0.01389 ]

# %%
import numpy as np

max_grads_hist = []
n = []
for n_qubits, learning_rate in zip(all_qubits, learning_rates):
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    grad_file = f"MaxGrad_{exp_name}.npy"
    if grad_file in files:
        max_grads_hist.append(np.load(f"{output_path}/histories/{grad_file}"))
        print(f"Reading file {grad_file}")
        n.append(n_qubits)
    else:
        print(f"Missing file {grad_file}")
# Out:
# Reading file MaxGrad_t5_beta1-0_q8_qbm9_e1000_lr0-01389_sn0-0_dn0-0.npy

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))
for hist in max_grads_hist:
    ax.plot(hist, "-")
ax.set_xlabel("Epoch")
ax.set_ylabel("Max absolute value of gradients")
ax.set_yscale("log")
ax.legend([f"n={_}" for _ in n])

for _n, hist in zip(n, max_grads_hist):
    print(f"n = {_n}, max grad (first, last): {hist[0]}, {hist[-1]}")
# Out:
# n = 8, max grad (first, last): 0.18821923918741942, 2.4999362797199776e-06

# %%
qre_hist = []
n = []
for n_qubits, learning_rate in zip(all_qubits, learning_rates):
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    qre_file = f"QRE_{exp_name}.npy"
    if qre_file in files:
        qre_hist.append(np.load(f"{output_path}/histories/{qre_file}"))
        print(f"Reading file {qre_file}")
        n.append(n_qubits)
    else:
        print(f"Missing file {qre_file}")
# Out:
# Reading file QRE_t5_beta1-0_q8_qbm9_e1000_lr0-01389_sn0-0_dn0-0.npy

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))
for hist in qre_hist:
    ax.plot(hist, "-")
ax.set_xlabel("Epoch")
ax.set_ylabel("Quantum Relative Entropy")
ax.set_yscale("log")
ax.legend([f"n={_}" for _ in n])

for _n, hist in zip(n, qre_hist):
    print(f"n = {_n}, QRE (first, last): {hist[0]}, {hist[-1]}")
# Out:
# n = 8, QRE (first, last): 0.2910981902208736, 0.21675077901200712

# %%
results_files = os.listdir(f"{output_path}/results/")
target_params = []
model_params = []

n = []
for n_qubits, learning_rate in zip(all_qubits, learning_rates):
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    true_params_file = f"ParamsTrue_{exp_name}.npy"
    model_params_file = f"Params_{exp_name}.npy"
    if true_params_file in results_files:
        target_params.append(np.load(f"{output_path}/results/{true_params_file}"))
        print(f"Reading file {true_params_file}")
        n.append(n_qubits)
        if model_params_file in results_files:
            model_params.append(np.load(f"{output_path}/results/{model_params_file}"))
            print(f"Reading file {model_params_file}")
        else:
            print(f"Missing file {model_params_file}")
    else:
        print(f"Missing file {target_params}")
# Out:
# Reading file ParamsTrue_t5_beta1-0_q8_qbm9_e1000_lr0-01389_sn0-0_dn0-0.npy
# Reading file Params_t5_beta1-0_q8_qbm9_e1000_lr0-01389_sn0-0_dn0-0.npy

# %%
for _n, _target_params, _model_params in zip(n, target_params, model_params):
    print(f"n = {_n}, target params: {_target_params}")
    print(f"   --- model params after training: {_model_params}")
    print(f"   --- (beta-normalized) model params after training: {_model_params/(-target_beta)}"
    )
# Out:
# n = 8, target params: [0.34558419 0.82161814]
#    --- model params after training: [-1.90978566e-01 -2.90479987e-02 -7.12975333e-03 -2.90479987e-02
#  -7.12975333e-03 -1.67792559e-03 -7.19694620e-04 -7.12975333e-03
#  -2.90479987e-02 -7.12975333e-03 -2.90479987e-02 -7.19694620e-04
#  -1.67792559e-03 -1.90978566e-01 -1.67792559e-03 -7.19694620e-04
#  -2.90479987e-02 -7.12975333e-03 -7.19694620e-04 -1.67792559e-03
#  -7.12975333e-03 -2.90479987e-02 -1.90978566e-01 -2.90479987e-02
#  -7.12975333e-03 -7.12975333e-03 -2.90479987e-02 -1.90978566e-01
#   1.43584508e-16  5.60773457e-17  5.35716340e-17 -2.81531164e-17
#   2.99601200e-17  2.78760425e-17 -2.75808986e-17  2.77375056e-17]
#    --- (beta-normalized) model params after training: [ 1.90978566e-01  2.90479987e-02  7.12975333e-03  2.90479987e-02
#   7.12975333e-03  1.67792559e-03  7.19694620e-04  7.12975333e-03
#   2.90479987e-02  7.12975333e-03  2.90479987e-02  7.19694620e-04
#   1.67792559e-03  1.90978566e-01  1.67792559e-03  7.19694620e-04
#   2.90479987e-02  7.12975333e-03  7.19694620e-04  1.67792559e-03
#   7.12975333e-03  2.90479987e-02  1.90978566e-01  2.90479987e-02
#   7.12975333e-03  7.12975333e-03  2.90479987e-02  1.90978566e-01
#  -1.43584508e-16 -5.60773457e-17 -5.35716340e-17  2.81531164e-17
#  -2.99601200e-17 -2.78760425e-17  2.75808986e-17 -2.77375056e-17]

# %% [markdown]
# We can also check the training histories as a function of the inverse temperature $\beta$

# %%
all_betas = [0.5, 1.0, 2.0, 4.0]
n_qubits = 8

# %%
qre_hist = []
b = []
for target_beta in all_betas:
    exp_name = get_exp_name(
        target_label,
        target_beta,
        n_qubits,
        model_label,
        epochs,
        learning_rate,
        shot_noise_sigma,
        depolarizing_noise,
    )

    qre_file = f"QRE_{exp_name}.npy"
    if qre_file in files:
        qre_hist.append(np.load(f"{output_path}/histories/{qre_file}"))
        print(f"Reading file {qre_file}")
        b.append(target_beta)
    else:
        print(f"Missing file {qre_file}")
# Out:
# Reading file QRE_t5_beta0-5_q8_qbm9_e1000_lr0-01389_sn0-0_dn0-0.npy
# Reading file QRE_t5_beta1-0_q8_qbm9_e1000_lr0-01389_sn0-0_dn0-0.npy
# Reading file QRE_t5_beta2-0_q8_qbm9_e1000_lr0-01389_sn0-0_dn0-0.npy
# Reading file QRE_t5_beta4-0_q8_qbm9_e1000_lr0-01389_sn0-0_dn0-0.npy

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))
for hist in qre_hist:
    ax.plot(hist[1:], "-")
ax.set_xlabel("Epoch")
ax.set_ylabel("Quantum Relative Entropy")
ax.set_yscale("log")
ax.legend([rf"$\beta$={_}" for _ in b])
